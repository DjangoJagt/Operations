# %%
# Gurobi for optimization
from gurobipy import GRB, Model, quicksum
import gurobipy as gp

# Pandas for data manipulation
import pandas as pd

# Numpy for numerical operations
import numpy as np

# Matplotlib for visualization
import matplotlib.pyplot as plt

# Datetime for handling time-related data
import datetime

# Pickle for saving/loading objects (optional, based on need)
import pickle

# %%
# Seed for reproducibility
np.random.seed(46)


# Define basic parameters for new flights
num_original_flights = 50
num_new_flights = 50
total_flights = num_original_flights + num_new_flights

# Generate flight IDs for 100 flights
flight_ids = [f"F{i:02d}" for i in range(1, total_flights + 1)]

arrival_times = [
        '09:00', '08:30', '09:00', '08:30', '08:15', '07:30', '10:15', '10:00', '10:25', '10:40',
        '11:00', '11:00', '11:15', '11:30', '11:30', '12:00', '11:45', '11:50', '11:55', '12:10',
        '12:45', '12:05', '12:10', '12:20', '12:20', '12:20', '12:30', '12:25', '12:40', '12:55',
        '12:50', '12:00', '13:00', '13:10', '14:25', '14:30', '14:00', '14:55', '15:00', '19:55',
        '18:30', '19:30', '18:55', '21:00', '20:10', '20:00', '22:30', '21:25', '21:30', '22:15'
    ]
departure_times = [
        '09:50', '09:10', '09:50', '10:20', '09:00', '08:50', '11:20', '10:50', '11:55', '11:35',
        '12:35', '12:25', '12:15', '12:20', '12:40', '13:55', '13:40', '12:45', '12:55', '14:00',
        '14:30', '13:00', '13:30', '13:20', '13:40', '13:30', '14:10', '14:10', '14:40', '13:40',
        '14:30', '12:55', '14:25', '14:45', '16:10', '15:20', '15:20', '16:00', '15:50', '21:25',
        '19:25', '20:50', '19:55', '22:55', '22:00', '21:15', '23:25', '23:15', '22:45', '23:10'
    ]
passenger_numbers = [
        140, 138, 340, 293, 252, 105, 130, 166, 191, 178,
        293, 166, 255, 183, 176, 220, 173, 145, 118, 153,
        256, 104, 269, 140, 142, 129, 190, 142, 163, 185,
        258, 133, 156, 120, 193, 300, 104, 219, 239, 111,
        166, 242, 167, 278, 195, 144, 219, 253, 158, 276
    ]
flight_types = [
        'Domestic', 'Domestic', 'International', 'International', 'International',
        'Domestic', 'Domestic', 'Domestic', 'International', 'Domestic',
        'International', 'Domestic', 'International', 'International', 'Domestic',
        'International', 'Domestic', 'Domestic', 'Domestic', 'Domestic',
        'International', 'Domestic', 'International', 'Domestic', 'Domestic',
        'Domestic', 'International', 'Domestic', 'Domestic', 'International',
        'International', 'Domestic', 'Domestic', 'Domestic', 'International',
        'International', 'Domestic', 'International', 'International', 'Domestic',
        'Domestic', 'International', 'Domestic', 'International', 'International',
        'Domestic', 'International', 'International', 'Domestic', 'International'
    ]

# Helper function to generate random times within a certain range
def generate_random_time(start_hour, end_hour):
    """Generate a random time string between start_hour and end_hour."""
    hour = np.random.randint(start_hour, end_hour)
    minute = np.random.choice([0, 15, 30, 45])
    return f"{hour:02d}:{minute:02d}"

# Function to ensure departure is logically after arrival and before 24:00
def ensure_logical_times(num_flights):
    max_arrival_minute = 23.5 * 60  # 23:30 in minutes
    max_departure_minute = 24 * 60  # 24:00 in minutes
    arrival_times = []
    departure_times = []
    for _ in range(num_flights):
        arrival = generate_random_time(8, 23)  # Allow arrivals up to 23:30
        arrival_minutes = int(arrival.split(':')[0]) * 60 + int(arrival.split(':')[1])
        # Ensure arrival time does not exceed 23:30
        if arrival_minutes > max_arrival_minute:
            arrival_minutes = max_arrival_minute
            arrival = f"{arrival_minutes // 60:02d}:{arrival_minutes % 60:02d}"
        
        # Define the latest departure time as the minimum between the flight's max duration and 24:00
        latest_departure_time = min(arrival_minutes + 360, max_departure_minute)
        departure_minutes = np.random.randint(arrival_minutes + 30, latest_departure_time + 1)
        departure = f"{departure_minutes // 60:02d}:{departure_minutes % 60:02d}"
        arrival_times.append(arrival)
        departure_times.append(departure)
    return arrival_times, departure_times

# Generate additional data for new flights
new_types = np.random.choice(['Domestic', 'International'], num_new_flights)
new_passengers = np.random.randint(100, 350, num_new_flights)
new_arrival_times, new_departure_times = ensure_logical_times(num_new_flights)

# Combine existing and new flight data
flight_types = np.concatenate((flight_types, new_types))
passenger_numbers = np.concatenate((passenger_numbers, new_passengers))
arrival_times = np.concatenate((arrival_times, new_arrival_times))
departure_times = np.concatenate((departure_times, new_departure_times))

# Convert times to minutes since midnight for consistency with previous code
def time_to_minutes(t):
    h, m = map(int, t.split(':'))
    return h * 60 + m

arrival_times = [time_to_minutes(t) for t in arrival_times]
departure_times = [time_to_minutes(t) for t in departure_times]

flight_data = pd.DataFrame({
    'flight_id': flight_ids,
    'arrival_time': arrival_times,
    'departure_time': departure_times,
    'passenger_number': passenger_numbers,
    'flight_type': flight_types
})

# Gate IDs
gate_ids = [f"Gate {i}" for i in range(1, 26)]
gate_types = ['Domestic' if i in [1, 2, 5, 7, 8, 10, 12, 13, 15, 16, 19, 22, 23, 25] else 'International' for i in range(1, 26)]

gate_data = pd.DataFrame({
    'gate_id': gate_ids,
    'gate_type': gate_types
})


# Manually entered distances from the provided matrix
distances = [
    [0, 2, 4, 6, 8, 8, 6, 6, 8, 10, 10, 8, 10, 12, 12, 18, 20, 22, 20, 18, 18, 20, 22, 20, 18],
    [2, 0, 2, 4, 6, 6, 4, 4, 6, 8, 8, 6, 8, 10, 10, 16, 18, 20, 18, 16, 16, 18, 20, 18, 16],
    [4, 2, 0, 2, 4, 4, 2, 2, 4, 6, 6, 4, 6, 8, 8, 14, 16, 18, 16, 14, 14, 16, 18, 16, 14],
    [6, 4, 2, 0, 2, 2, 0, 2, 4, 6, 6, 4, 6, 8, 8, 14, 16, 18, 16, 14, 14, 16, 18, 16, 14],
    [8, 6, 4, 2, 0, 0, 2, 4, 6, 8, 8, 6, 8, 10, 10, 16, 18, 20, 18, 16, 16, 18, 20, 18, 16],
    [8, 6, 4, 2, 0, 0, 2, 4, 6, 8, 8, 6, 8, 10, 10, 16, 18, 20, 18, 16, 16, 18, 20, 18, 16],
    [6, 4, 2, 0, 2, 2, 0, 2, 4, 6, 6, 4, 6, 8, 8, 14, 16, 18, 16, 14, 14, 16, 18, 16, 14],
    [6, 4, 2, 2, 4, 4, 2, 0, 2, 4, 4, 2, 4, 6, 6, 12, 14, 16, 14, 12, 12, 14, 16, 14, 12],
    [8, 6, 4, 4, 6, 6, 4, 2, 0, 2, 2, 0, 2, 4, 4, 14, 16, 18, 16, 14, 14, 16, 18, 16, 14],
    [10, 8, 6, 6, 8, 8, 6, 4, 2, 0, 0, 2, 4, 6, 6, 16, 18, 20, 18, 16, 16, 18, 20, 18, 16],
    [10, 8, 6, 6, 8, 8, 6, 4, 2, 0, 0, 2, 4, 6, 6, 16, 18, 20, 18, 16, 16, 18, 20, 18, 16],
    [8, 6, 4, 4, 6, 6, 4, 2, 0, 2, 2, 0, 2, 4, 4, 14, 16, 18, 16, 14, 14, 16, 18, 16, 14],
    [10, 8, 6, 6, 8, 8, 6, 4, 2, 4, 4, 2, 0, 2, 2, 16, 18, 20, 18, 16, 16, 18, 20, 18, 16],
    [12, 10, 8, 8, 10, 10, 8, 6, 4, 6, 6, 4, 2, 0, 2, 18, 20, 22, 20, 18, 18, 20, 22, 20, 18],
    [12, 10, 8, 8, 10, 10, 8, 6, 4, 6, 6, 4, 2, 2, 0, 18, 20, 22, 20, 18, 18, 20, 22, 20, 18],
    [18, 16, 14, 14, 16, 16, 14, 12, 14, 16, 16, 14, 16, 18, 18, 0, 2, 4, 2, 0, 0, 2, 4, 2, 0],
    [20, 18, 16, 16, 18, 18, 16, 14, 16, 18, 18, 16, 18, 20, 20, 2, 0, 2, 0, 2, 2, 4, 6, 4, 2],
    [22, 20, 18, 18, 20, 20, 18, 16, 18, 20, 20, 18, 20, 22, 22, 4, 2, 0, 2, 4, 4, 6, 8, 6, 4],
    [20, 18, 16, 16, 18, 18, 16, 14, 16, 18, 18, 16, 18, 20, 20, 2, 0, 2, 0, 2, 2, 4, 6, 4, 2],
    [18, 16, 14, 14, 16, 16, 14, 12, 14, 16, 16, 14, 16, 18, 18, 0, 2, 4, 2, 0, 0, 2, 4, 2, 0],
    [18, 16, 14, 14, 16, 16, 14, 12, 14, 16, 16, 14, 16, 18, 18, 0, 2, 4, 2, 0, 0, 2, 4, 2, 0],
    [20, 18, 16, 16, 18, 18, 16, 14, 16, 18, 18, 16, 18, 20, 20, 2, 4, 6, 4, 2, 2, 0, 2, 0, 2],
    [22, 20, 18, 18, 20, 20, 18, 16, 18, 20, 20, 18, 20, 22, 22, 4, 6, 8, 6, 4, 4, 2, 0, 2, 4],
    [20, 18, 16, 16, 18, 18, 16, 14, 16, 18, 18, 16, 18, 20, 20, 2, 4, 6, 4, 2, 2, 0, 2, 0, 2],
    [18, 16, 14, 14, 16, 16, 14, 12, 14, 16, 16, 14, 16, 18, 18, 0, 2, 4, 2, 0, 0, 2, 4, 2, 0]
]

# Convert distances array to DataFrame for better readability
distance_df = pd.DataFrame(distances, index=gate_ids, columns=gate_ids)


# Distances to the exit
ed_k = [3 if i in [1, 2, 3, 8, 13, 14, 15] else 5 if i in [4, 7, 9, 12] else 7 if i in [5, 6, 10, 11] else 14 for i in range(1, 26)]

# Store number of flights and gates
num_flights = len(flight_data)
num_gates = len(gate_data)

# Identify large aircraft (more than 240 passengers)
large_aircraft = [i for i in range(num_flights) if passenger_numbers[i] > 240]

# Define large gates (where large aircraft can be assigned)
large_gates = [0, 4, 10, 14, 15, 17, 19, 20, 22, 24]  # Corresponding to gates 1, 5, 11, 15, 16, 18, 20, 21, 23, 25 in 0-based indexing

# Generate transiting passengers data (p_ij) with constraints
p_ij = np.zeros((num_flights, num_flights), dtype=int)

for i in range(num_flights):
    max_transit_passengers = passenger_numbers[i] // 2  # Maximum of 50% of the total passengers
    remaining_passengers = max_transit_passengers
    transfer_flights = np.random.choice([x for x in range(num_flights) if x != i], 2, replace=False)  # Choose 2 different flights
    for j in transfer_flights:
        if remaining_passengers > 0:
            p_ij[i, j] = np.random.randint(0, min(50, remaining_passengers + 1))
            remaining_passengers -= p_ij[i, j]

# Second pass to ensure inflow constraints are met
for j in range(num_flights):
    total_inflow = sum(p_ij[i, j] for i in range(num_flights))
    if total_inflow > passenger_numbers[j]:
        excess_passengers = total_inflow - passenger_numbers[j]
        inflow_flights = [i for i in range(num_flights) if p_ij[i, j] > 0]
        
        while excess_passengers > 0 and inflow_flights:
            i = inflow_flights.pop()
            reduction = min(p_ij[i, j], excess_passengers)
            p_ij[i, j] -= reduction
            excess_passengers -= reduction

# Verify generated data
# print("Flight Data:")
# print(flight_data.head(num_flights)
# print(flight_data.iloc[93:94])
#print(flight_data.tail(50))

# print("\nGate Data:")
# print(gate_data.head(num_gates))

# print("\nDistance Matrix (d_kl):")
# print(distance_df)

# print("\nDistance to Entrance/Exit (ed_k):")
# print(pd.Series(ed_k, index=gate_ids))

# print("\nTransiting Passengers (p_ij):")
# print(pd.DataFrame(p_ij, index=flight_ids, columns=flight_ids).head(num_flights))

# %% [markdown]
# ### Model Explanation
#
# The objective of the FC formulation is to minimize the total walking distance of passengers at the airport, considering both transfer passengers and non-transfer passengers. The model includes the following key components:
#
# - **Parameters**:
#   - `num_flights`: Number of flights
#   - `num_gates`: Number of gates
#   - `arrival_times`: Arrival times of flights
#   - `departure_times`: Departure times of flights
#   - `passenger_numbers`: Number of passengers per flight
#   - `flight_types`: Type of flight (domestic/international)
#   - `gate_types`: Type of gate (domestic/international)
#   - `distances`: Distance matrix between gates
#
# - **Decision Variables**:
#   - `x[i, k]`: Binary variable, 1 if flight \(i\) is assigned to gate \(k\), 0 otherwise
#   - `w[i, k, l]`: Continuous variable representing the number of passengers from flight \(i\) through gate \(k\) to gate \(l\)
#
# - **Objective Function**:
#   - Minimize the total walking distance of passengers.
#
# - **Constraints**:
#   - Each flight must be assigned to exactly one gate.
#   - Gates cannot be double-booked.
#   - Flow balance constraints for transfer passengers.

# %%
# Initialize the Gurobi model
model = Model("FC_Formulation")

# Distance penalty for the apron
apron_distance_penalty = 30

# Distance matrices
d_kl = np.zeros((num_gates + 1, num_gates + 1))
d_kl[:num_gates, :num_gates] = distance_df.values
d_kl[num_gates, :] = apron_distance_penalty  # Distance from apron to all gates
d_kl[:, num_gates] = apron_distance_penalty  # Distance from all gates to apron
d_kl[num_gates, num_gates] = apron_distance_penalty  # Distance from apron to itself

# Distance to/from exit for each gate (including apron)
ed_k = np.append(ed_k, apron_distance_penalty)  # Append apron distance to exit

# print(d_kl,ed_k)
# Passengers data
e_i = flight_data['passenger_number'].values - np.sum(p_ij, axis=1)
f_i = flight_data['passenger_number'].values - np.sum(p_ij, axis=0)

# Aircraft type (domestic/international)
g_i = flight_data['flight_type'].apply(lambda x: 'D' if x == 'Domestic' else 'I').values

# Sets of domestic and international gates
K_D = [k for k, t in zip(range(num_gates), gate_types) if t == 'Domestic']
K_I = [k for k, t in zip(range(num_gates), gate_types) if t == 'International']
K_D.append(num_gates)  # Add apron to domestic gates
K_I.append(num_gates)  # Add apron to international gates

# Number of gates
m = num_gates

# Generating overlap sets for all time steps
def generate_overlap_sets(flight_data):
    # Initialize dictionaries to hold overlap sets
    I_Dt = []
    I_It = []
    T_D = {}
    T_I = {}
    
    # Iterate through each minute of the day
    for t in range(1440):
        domestic_overlaps = set()
        international_overlaps = set()
        
        # Check for overlapping flights at time t
        for i, flight in flight_data.iterrows():
            if flight['arrival_time'] <= t < flight['departure_time']:
                if flight['flight_type'] == 'Domestic':
                    domestic_overlaps.add(flight['flight_id'])
                else:
                    international_overlaps.add(flight['flight_id'])
        
        if domestic_overlaps:
            I_Dt.append(domestic_overlaps)
        if international_overlaps:
            I_It.append(international_overlaps)
    
    # Convert I_Dt and I_It to T_D and T_I
    for idx, overlap_set in enumerate(I_Dt):
        if overlap_set:
            T_D[f"TD{idx+1}"] = overlap_set
            
    for idx, overlap_set in enumerate(I_It):
        if overlap_set:
            T_I[f"TI{idx+1}"] = overlap_set
    
    return T_D, T_I

# Generate overlap sets
T_D, T_I = generate_overlap_sets(flight_data)

# # Print overlap sets
# print("Overlap Sets for Domestic Flights (T_D):")
# for key, value in T_D.items():
#     print(f"{key}: {value}")

# print("\nOverlap Sets for International Flights (T_I):")
# for key, value in T_I.items():
#     print(f"{key}: {value}")

# Decision Variables
x = model.addVars(num_flights, num_gates + 1, vtype=GRB.BINARY, name="x")
w = model.addVars(num_flights, num_gates + 1, num_gates + 1, vtype=GRB.CONTINUOUS, name="w")

# Verify variables
print("Decision variables defined.")
# Out:
# Decision variables defined.

# %%
# Objective function components\n",
objective = quicksum(d_kl[k, l] * w[i, k, l] for i in range(num_flights) for k in range(num_gates + 1) for l in range(num_gates + 1)) + \
            quicksum((e_i[i] + f_i[i]) * ed_k[k] * x[i, k] for i in range(num_flights) for k in range(num_gates + 1))

model.setObjective(objective, GRB.MINIMIZE)

# Verify objective
print("Objective function defined.")
# Out:
# Objective function defined.

# %%
# Constraint 3: Assign each aircraft to exactly one gate
for i in range(num_flights):
    if g_i[i] == 'D':
        model.addConstr(quicksum(x[i, k] for k in K_D) == 1, name=f"Assign_Domestic_{i}")
    else:
        model.addConstr(quicksum(x[i, k] for k in K_I) == 1, name=f"Assign_International_{i}")

# Add Constraints (4) and (5): At most one aircraft can be assigned to a fixed gate during a certain time interval
# Constraint (4) for domestic flights (excluding apron)
for t, I_Dt in T_D.items():
    for k in K_D[:-1]:  # Exclude the apron
        model.addConstr(quicksum(x[flight_ids.index(flight), k] for flight in I_Dt) <= 1, name=f"MaxOneAircraft_Domestic_{t}_Gate{k}")

# Constraint (5) for international flights (excluding apron)
for t, I_It in T_I.items():
    for k in K_I[:-1]:  # Exclude the apron
        model.addConstr(quicksum(x[flight_ids.index(flight), k] for flight in I_It) <= 1, name=f"MaxOneAircraft_International_{t}_Gate{k}")

# # Constraint 6: Minimum apron assignments
# model.addConstr(quicksum(x[i, num_gates] for i in range(num_flights)) <= 5, name="min_apron_assignments")

# Constraint (10): Passenger flow balance constraints (outbound)
for i in range(num_flights):
    gate_set = K_D if g_i[i] == 'D' else K_I  # Select the appropriate gate set
    for k in gate_set:
        model.addConstr(
            quicksum(w[i, k, l] for l in range(num_gates + 1)) == x[i, k] * sum(p_ij[i, j] for j in range(num_flights)),
            name=f"FlowBalance_{i}_{k}"
        )

# Constraint 11: Passenger flow balance constraints (inbound)
for i in range(num_flights):
    gate_set = K_D if g_i[i] == 'D' else K_I  # Select the appropriate gate set
    for k in range(num_gates + 1):  # Iterate over all gates including the apron
        model.addConstr(
            quicksum(w[i, l, k] for l in gate_set) == 
            quicksum(p_ij[i, j] * x[j, k] for j in range(num_flights)),
            name=f"PassengerFlow_{i}_{k}"
        )

# Constraint 12: Non-negativity of flow variables
for i in range(num_flights):
    gate_set = K_D if g_i[i] == 'D' else K_I  # Select the appropriate gate set
    for k in gate_set:
        for l in range(num_gates + 1):  # Iterate over all gates including the apron
            model.addConstr(
                w[i, k, l] >= 0,
                name=f"NonNegativeFlow_{i}_{k}_{l}"
            )

# Constraint (13): Ensure that overlapping domestic aircraft are assigned to the apron
for t, I_Dt in T_D.items():
    if len(I_Dt) > len(K_D) - 1:  # K_D includes the apron, so len(K_D) - 1 is the number of fixed gates
        model.addConstr(
            quicksum(x[flight_ids.index(flight), num_gates] for flight in I_Dt) >= len(I_Dt) - (len(K_D) - 1),
            name=f"ApronAssignment_Domestic_{t}"
        )

# Constraint (14): Ensure that overlapping international aircraft are assigned to the apron
for t, I_It in T_I.items():
    if len(I_It) > len(K_I) - 1:  # K_I includes the apron, so len(K_I) - 1 is the number of fixed gates
        model.addConstr(
            quicksum(x[flight_ids.index(flight), num_gates] for flight in I_It) >= len(I_It) - (len(K_I) - 1),
            name=f"ApronAssignment_International_{t}"
        )

# Constraint (15) for large domestic aircraft to only be assigned to large domestic gates or the apron
for i in range(num_flights):
    if i in large_aircraft and g_i[i] == 'D':
        model.addConstr(quicksum(x[i, k] for k in large_gates if k in K_D) + x[i, num_gates] == 1, name=f"LargeDomesticAircraft_Assignment_{i}")

# Constraint (15) for large international aircraft to only be assigned to large international gates or the apron
for i in range(num_flights):
    if i in large_aircraft and g_i[i] == 'I':
        model.addConstr(quicksum(x[i, k] for k in large_gates if k in K_I) + x[i, num_gates] == 1, name=f"LargeInternationalAircraft_Assignment_{i}")


# Verify constraints
print("Constraints defined.")
# Out:
# Constraints defined.

# %%
# Optimize model
model.optimize()

# Print results
if model.status == GRB.OPTIMAL:
    # Print flight assignments to gates
    for i in range(num_flights):
        for k in range(num_gates + 1):
            if x[i, k].X > 0.5:  # Check if the flight is assigned to the gate
                gate = 'Apron' if k == num_gates else gate_ids[k]
                print(f"Flight {flight_data.loc[i, 'flight_id']} is assigned to {gate}")
    
    # Print the flow of passengers between gates and to the exit
    print("\nPassenger Flow Between Gates and to the Exit:")
    for i in range(num_flights):
        for k in range(num_gates + 1):
            gate_from = 'Apron' if k == num_gates else gate_ids[k]
            total_transfer_passengers = 0
            # Flow to other gates
            for l in range(num_gates + 1):
                if w[i, k, l].X > 0:  # Only print non-zero flows
                    gate_to = 'Apron' if l == num_gates else gate_ids[l]
                    print(f"Flow from Flight {flight_data.loc[i, 'flight_id']} at {gate_from} to {gate_to}: {w[i, k, l].X}")
                    total_transfer_passengers += w[i, k, l].X
            # Flow to exit
            if x[i, k].X > 0.5:
                passengers_to_exit = flight_data.loc[i, 'passenger_number'] - total_transfer_passengers
                if passengers_to_exit > 0:
                    print(f"Flow from Flight {flight_data.loc[i, 'flight_id']} at {gate_from} to Exit: {passengers_to_exit}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 63881 rows, 70200 columns and 263718 nonzeros
# Model fingerprint: 0x9c31236c
# Variable types: 67600 continuous, 2600 integer (2600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   Objective range  [2e+00, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 59706 rows and 40829 columns
# Presolve time: 0.45s
# Presolved: 4175 rows, 29371 columns, 65064 nonzeros
# Variable types: 27280 continuous, 2091 integer (2091 binary)
# Found heuristic solution: objective 1001534.0000
# Found heuristic solution: objective 476999.00000
#
# Root relaxation: objective 3.039547e+05, 5205 iterations, 0.85 seconds (0.88 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 303954.699    0  292 476999.000 303954.699  36.3%     -    1s
# H    0     0                    328642.00000 303954.699  7.51%     -    1s
# H    0     0                    327136.00000 303954.699  7.09%     -    1s
# H    0     0                    320432.00000 303954.699  5.14%     -    2s
#      0     0 305282.037    0  299 320432.000 305282.037  4.73%     -    3s
# H    0     0                    309690.00000 305330.220  1.41%     -    7s
# H    0     0                    309624.00000 305330.220  1.39%     -    7s
#      0     0 305330.220    0  309 309624.000 305330.220  1.39%     -    7s
#      0     0 305330.220    0  311 309624.000 305330.220  1.39%     -    7s
#      0     0 305330.220    0  310 309624.000 305330.220  1.39%     -    7s
#      0     0 305618.405    0  340 309624.000 305618.405  1.29%     -    8s
#      0     0 305672.609    0  341 309624.000 305672.609  1.28%     -    9s
#      0     0 305684.085    0  346 309624.000 305684.085  1.27%     -    9s
#      0     0 305689.980    0  344 309624.000 305689.980  1.27%     -    9s
#      0     0 305690.345    0  343 309624.000 305690.345  1.27%     -    9s
#      0     0 305690.541    0  346 309624.000 305690.541  1.27%     -    9s
#      0     0 305830.374    0  326 309624.000 305830.374  1.23%     -   10s
# H    0     0                    309599.00000 305858.457  1.21%     -   10s
#      0     0 305858.457    0  327 309599.000 305858.457  1.21%     -   10s
#      0     0 305858.457    0  336 309599.000 305858.457  1.21%     -   10s
#      0     0 305858.457    0  337 309599.000 305858.457  1.21%     -   10s
#      0     0 305858.457    0  327 309599.000 305858.457  1.21%     -   10s
#      0     0 305913.419    0  337 309599.000 305913.419  1.19%     -   11s
# H    0     0                    309495.00000 305920.825  1.15%     -   11s
#      0     0 305933.731    0  345 309495.000 305933.731  1.15%     -   11s
#      0     0 305935.269    0  341 309495.000 305935.269  1.15%     -   11s
#      0     0 305935.475    0  339 309495.000 305935.475  1.15%     -   11s
#      0     0 305951.283    0  338 309495.000 305951.283  1.14%     -   11s
#      0     0 305957.232    0  345 309495.000 305957.232  1.14%     -   12s
#      0     0 305959.561    0  330 309495.000 305959.561  1.14%     -   12s
#      0     0 305959.623    0  334 309495.000 305959.623  1.14%     -   12s
# H    0     0                    309431.00000 306111.129  1.07%     -   12s
#      0     0 306111.129    0  331 309431.000 306111.129  1.07%     -   12s
#      0     0 306124.971    0  342 309431.000 306124.971  1.07%     -   13s
#      0     0 306127.649    0  344 309431.000 306127.649  1.07%     -   13s
#      0     0 306128.066    0  342 309431.000 306128.066  1.07%     -   13s
#      0     0 306148.426    0  325 309431.000 306148.426  1.06%     -   13s
#      0     0 306148.426    0  296 309431.000 306148.426  1.06%     -   14s
# H    0     0                    309327.00000 306148.426  1.03%     -   15s
#      0     0 306148.426    0  319 309327.000 306148.426  1.03%     -   16s
#      0     0 306148.426    0  324 309327.000 306148.426  1.03%     -   19s
#      0     0 306148.426    0  320 309327.000 306148.426  1.03%     -   19s
#      0     0 306148.426    0  319 309327.000 306148.426  1.03%     -   19s
#      0     0 306148.426    0  333 309327.000 306148.426  1.03%     -   19s
#      0     0 306148.426    0  321 309327.000 306148.426  1.03%     -   20s
#      0     0 306168.995    0  340 309327.000 306168.995  1.02%     -   20s
#      0     0 306172.264    0  334 309327.000 306172.264  1.02%     -   20s
#      0     0 306172.496    0  343 309327.000 306172.496  1.02%     -   20s
#      0     0 306177.173    0  333 309327.000 306177.173  1.02%     -   20s
#      0     0 306189.981    0  346 309327.000 306189.981  1.01%     -   20s
#      0     0 306218.032    0  319 309327.000 306218.032  1.01%     -   21s
#      0     0 306233.248    0  301 309327.000 306233.248  1.00%     -   21s
#      0     0 306233.248    0  308 309327.000 306233.248  1.00%     -   21s
#      0     0 306233.248    0  321 309327.000 306233.248  1.00%     -   21s
#      0     0 306233.248    0  304 309327.000 306233.248  1.00%     -   21s
#      0     0 306243.723    0  301 309327.000 306243.723  1.00%     -   22s
#      0     0 306243.723    0  307 309327.000 306243.723  1.00%     -   22s
#      0     0 306243.723    0  308 309327.000 306243.723  1.00%     -   22s
#      0     0 306243.723    0  307 309327.000 306243.723  1.00%     -   22s
#      0     0 306246.208    0  303 309327.000 306246.208  1.00%     -   22s
#      0     2 306264.867    0  299 309327.000 306264.867  0.99%     -   25s
#     37    46 308911.918    6  286 309327.000 306996.646  0.75%   935   30s
#    105   114 308517.853   11  255 309327.000 306996.646  0.75%   654   35s
# H  132   140                    309271.00000 306996.646  0.74%   569   35s
#    255   195 308910.794   12  211 309271.000 306996.646  0.74%   402   42s
#    347   238 307932.281    5  269 309271.000 307159.425  0.68%   360   45s
#    462   276 308597.594    9  244 309271.000 307159.425  0.68%   356   50s
#    557   300 308343.663    7  256 309271.000 307452.995  0.59%   366   55s
#    707   364 308278.666    7  241 309271.000 307770.427  0.49%   351   60s
#    843   400 308806.461    6  284 309271.000 307910.531  0.44%   341   65s
#    960   426 infeasible    8      309271.000 308028.921  0.40%   343   70s
#   1149   469     cutoff    8      309271.000 308130.759  0.37%   332   76s
#   1341   490     cutoff   19      309271.000 308244.469  0.33%   327   80s
#   1458   516 308970.470   10  221 309271.000 308280.124  0.32%   324   85s
#   1741   557 308935.554   11  206 309271.000 308373.343  0.29%   313   91s
#   1934   569     cutoff   15      309271.000 308426.741  0.27%   308   96s
#   2193   585     cutoff   12      309271.000 308479.926  0.26%   299  101s
#   2392   589 308987.712   13  211 309271.000 308522.924  0.24%   294  107s
#   2522   580 309196.630   15  119 309271.000 308560.364  0.23%   293  110s
#   2839   578 308838.310   13  225 309271.000 308615.451  0.21%   287  116s
#   2945   578 309078.931   17  150 309271.000 308633.423  0.21%   285  123s
#   3061   567     cutoff   16      309271.000 308655.740  0.20%   284  127s
#   3236   530 308904.806   14  269 309271.000 308675.199  0.19%   283  131s
#   3418   513 309085.466   12  266 309271.000 308722.760  0.18%   282  135s
#   3862   400     cutoff   15      309271.000 308807.497  0.15%   278  143s
#   4124   314     cutoff    9      309271.000 308873.297  0.13%   275  147s
#   4482   163     cutoff   12      309271.000 308928.623  0.11%   267  153s
#   4713     0 309093.176   12  209 309271.000 308949.984  0.10%   262  155s
#
# Cutting planes:
#   Implied bound: 190
#   MIR: 131
#   Flow cover: 581
#   Inf proof: 4
#   RLT: 5
#   Relax-and-lift: 33
#
# Explored 4927 nodes (1289112 simplex iterations) in 155.46 seconds (128.42 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 309271 309327 309431 ... 328642
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.092710000000e+05, best bound 3.092710000000e+05, gap 0.0000%
# Flight F01 is assigned to Gate 8
# Flight F02 is assigned to Gate 13
# Flight F03 is assigned to Gate 11
# Flight F04 is assigned to Gate 20
# Flight F05 is assigned to Gate 11
# Flight F06 is assigned to Gate 8
# Flight F07 is assigned to Gate 13
# Flight F08 is assigned to Gate 8
# Flight F09 is assigned to Gate 14
# Flight F10 is assigned to Gate 2
# Flight F11 is assigned to Gate 11
# Flight F12 is assigned to Gate 8
# Flight F13 is assigned to Gate 20
# Flight F14 is assigned to Gate 4
# Flight F15 is assigned to Gate 7
# Flight F16 is assigned to Gate 14
# Flight F17 is assigned to Gate 19
# Flight F18 is assigned to Gate 10
# Flight F19 is assigned to Apron
# Flight F20 is assigned to Gate 2
# Flight F21 is assigned to Gate 20
# Flight F22 is assigned to Apron
# Flight F23 is assigned to Gate 21
# Flight F24 is assigned to Gate 15
# Flight F25 is assigned to Gate 22
# Flight F26 is assigned to Apron
# Flight F27 is assigned to Gate 4
# Flight F28 is assigned to Gate 8
# Flight F29 is assigned to Gate 7
# Flight F30 is assigned to Gate 3
# Flight F31 is assigned to Gate 11
# Flight F32 is assigned to Gate 13
# Flight F33 is assigned to Gate 13
# Flight F34 is assigned to Gate 10
# Flight F35 is assigned to Gate 4
# Flight F36 is assigned to Gate 21
# Flight F37 is assigned to Gate 2
# Flight F38 is assigned to Gate 3
# Flight F39 is assigned to Gate 14
# Flight F40 is assigned to Gate 13
# Flight F41 is assigned to Gate 13
# Flight F42 is assigned to Apron
# Flight F43 is assigned to Gate 8
# Flight F44 is assigned to Gate 20
# Flight F45 is assigned to Gate 14
# Flight F46 is assigned to Gate 8
# Flight F47 is assigned to Gate 14
# Flight F48 is assigned to Gate 21
# Flight F49 is assigned to Gate 13
# Flight F50 is assigned to Gate 11
# Flight F51 is assigned to Gate 6
# Flight F52 is assigned to Gate 4
# Flight F53 is assigned to Gate 16
# Flight F54 is assigned to Gate 23
# Flight F55 is assigned to Gate 15
# Flight F56 is assigned to Gate 9
# Flight F57 is assigned to Gate 25
# Flight F58 is assigned to Gate 11
# Flight F59 is assigned to Gate 11
# Flight F60 is assigned to Gate 8
# Flight F61 is assigned to Gate 9
# Flight F62 is assigned to Gate 15
# Flight F63 is assigned to Gate 6
# Flight F64 is assigned to Gate 1
# Flight F65 is assigned to Gate 12
# Flight F66 is assigned to Gate 15
# Flight F67 is assigned to Gate 3
# Flight F68 is assigned to Gate 3
# Flight F69 is assigned to Gate 16
# Flight F70 is assigned to Gate 12
# Flight F71 is assigned to Gate 21
# Flight F72 is assigned to Gate 3
# Flight F73 is assigned to Gate 25
# Flight F74 is assigned to Gate 5
# Flight F75 is assigned to Gate 5
# Flight F76 is assigned to Apron
# Flight F77 is assigned to Gate 2
# Flight F78 is assigned to Apron
# Flight F79 is assigned to Gate 7
# Flight F80 is assigned to Gate 1
# Flight F81 is assigned to Gate 1
# Flight F82 is assigned to Gate 10
# Flight F83 is assigned to Gate 15
# Flight F84 is assigned to Gate 2
# Flight F85 is assigned to Gate 3
# Flight F86 is assigned to Gate 6
# Flight F87 is assigned to Gate 5
# Flight F88 is assigned to Gate 13
# Flight F89 is assigned to Gate 12
# Flight F90 is assigned to Gate 1
# Flight F91 is assigned to Apron
# Flight F92 is assigned to Gate 8
# Flight F93 is assigned to Gate 9
# Flight F94 is assigned to Gate 15
# Flight F95 is assigned to Gate 1
# Flight F96 is assigned to Gate 7
# Flight F97 is assigned to Gate 21
# Flight F98 is assigned to Gate 20
# Flight F99 is assigned to Gate 18
# Flight F100 is assigned to Gate 17
#
# Passenger Flow Between Gates and to the Exit:
# Flow from Flight F01 at Gate 8 to Gate 8: 38.0
# Flow from Flight F01 at Gate 8 to Gate 20: 18.0
# Flow from Flight F01 at Gate 8 to Exit: 84.0
# Flow from Flight F02 at Gate 13 to Gate 8: 11.0
# Flow from Flight F02 at Gate 13 to Gate 15: 26.0
# Flow from Flight F02 at Gate 13 to Exit: 101.0
# Flow from Flight F03 at Gate 11 to Gate 2: 19.0
# Flow from Flight F03 at Gate 11 to Gate 11: 43.0
# Flow from Flight F03 at Gate 11 to Exit: 278.0
# Flow from Flight F04 at Gate 20 to Gate 2: 3.0
# Flow from Flight F04 at Gate 20 to Gate 8: 4.0
# Flow from Flight F04 at Gate 20 to Exit: 286.0
# Flow from Flight F05 at Gate 11 to Gate 10: 42.0
# Flow from Flight F05 at Gate 11 to Gate 13: 32.0
# Flow from Flight F05 at Gate 11 to Exit: 178.0
# Flow from Flight F06 at Gate 8 to Gate 3: 8.0
# Flow from Flight F06 at Gate 8 to Gate 17: 32.0
# Flow from Flight F06 at Gate 8 to Exit: 65.0
# Flow from Flight F07 at Gate 13 to Gate 8: 14.0
# Flow from Flight F07 at Gate 13 to Gate 9: 42.0
# Flow from Flight F07 at Gate 13 to Exit: 74.0
# Flow from Flight F08 at Gate 8 to Gate 8: 49.0
# Flow from Flight F08 at Gate 8 to Gate 25: 29.0
# Flow from Flight F08 at Gate 8 to Exit: 88.0
# Flow from Flight F09 at Gate 14 to Gate 1: 5.0
# Flow from Flight F09 at Gate 14 to Gate 15: 39.0
# Flow from Flight F09 at Gate 14 to Exit: 147.0
# Flow from Flight F10 at Gate 2 to Gate 2: 40.0
# Flow from Flight F10 at Gate 2 to Gate 3: 20.0
# Flow from Flight F10 at Gate 2 to Exit: 118.0
# Flow from Flight F11 at Gate 11 to Gate 3: 31.0
# Flow from Flight F11 at Gate 11 to Apron: 10.0
# Flow from Flight F11 at Gate 11 to Exit: 252.0
# Flow from Flight F12 at Gate 8 to Gate 3: 18.0
# Flow from Flight F12 at Gate 8 to Gate 21: 23.0
# Flow from Flight F12 at Gate 8 to Exit: 125.0
# Flow from Flight F13 at Gate 20 to Gate 1: 4.0
# Flow from Flight F13 at Gate 20 to Gate 12: 25.0
# Flow from Flight F13 at Gate 20 to Exit: 226.0
# Flow from Flight F14 at Gate 4 to Gate 20: 55.0
# Flow from Flight F14 at Gate 4 to Exit: 128.0
# Flow from Flight F15 at Gate 7 to Gate 20: 10.0
# Flow from Flight F15 at Gate 7 to Gate 21: 28.0
# Flow from Flight F15 at Gate 7 to Exit: 138.0
# Flow from Flight F16 at Gate 14 to Gate 7: 2.0
# Flow from Flight F16 at Gate 14 to Gate 12: 20.0
# Flow from Flight F16 at Gate 14 to Exit: 198.0
# Flow from Flight F17 at Gate 19 to Gate 20: 22.0
# Flow from Flight F17 at Gate 19 to Gate 22: 25.0
# Flow from Flight F17 at Gate 19 to Exit: 126.0
# Flow from Flight F18 at Gate 10 to Gate 9: 37.0
# Flow from Flight F18 at Gate 10 to Gate 21: 35.0
# Flow from Flight F18 at Gate 10 to Exit: 73.0
# Flow from Flight F19 at Apron to Gate 3: 47.0
# Flow from Flight F19 at Apron to Exit: 71.0
# Flow from Flight F20 at Gate 2 to Gate 7: 25.0
# Flow from Flight F20 at Gate 2 to Gate 8: 28.0
# Flow from Flight F20 at Gate 2 to Exit: 100.0
# Flow from Flight F21 at Gate 20 to Gate 3: 7.0
# Flow from Flight F21 at Gate 20 to Gate 15: 5.0
# Flow from Flight F21 at Gate 20 to Exit: 244.0
# Flow from Flight F22 at Apron to Gate 10: 5.0
# Flow from Flight F22 at Apron to Gate 13: 47.0
# Flow from Flight F22 at Apron to Exit: 52.0
# Flow from Flight F23 at Gate 21 to Gate 4: 84.0
# Flow from Flight F23 at Gate 21 to Exit: 185.0
# Flow from Flight F24 at Gate 15 to Gate 5: 4.0
# Flow from Flight F24 at Gate 15 to Gate 14: 38.0
# Flow from Flight F24 at Gate 15 to Exit: 98.0
# Flow from Flight F25 at Gate 22 to Gate 7: 16.0
# Flow from Flight F25 at Gate 22 to Gate 8: 43.0
# Flow from Flight F25 at Gate 22 to Exit: 83.0
# Flow from Flight F26 at Apron to Gate 17: 34.0
# Flow from Flight F26 at Apron to Exit: 95.0
# Flow from Flight F27 at Gate 4 to Gate 8: 40.0
# Flow from Flight F27 at Gate 4 to Gate 14: 10.0
# Flow from Flight F27 at Gate 4 to Exit: 140.0
# Flow from Flight F28 at Gate 8 to Gate 11: 26.0
# Flow from Flight F28 at Gate 8 to Gate 13: 23.0
# Flow from Flight F28 at Gate 8 to Exit: 93.0
# Flow from Flight F29 at Gate 7 to Gate 3: 44.0
# Flow from Flight F29 at Gate 7 to Apron: 6.0
# Flow from Flight F29 at Gate 7 to Exit: 113.0
# Flow from Flight F30 at Gate 3 to Gate 3: 40.0
# Flow from Flight F30 at Gate 3 to Gate 4: 10.0
# Flow from Flight F30 at Gate 3 to Exit: 135.0
# Flow from Flight F31 at Gate 11 to Gate 12: 4.0
# Flow from Flight F31 at Gate 11 to Gate 21: 5.0
# Flow from Flight F31 at Gate 11 to Exit: 249.0
# Flow from Flight F32 at Gate 13 to Gate 8: 25.0
# Flow from Flight F32 at Gate 13 to Gate 21: 15.0
# Flow from Flight F32 at Gate 13 to Exit: 93.0
# Flow from Flight F33 at Gate 13 to Gate 4: 4.0
# Flow from Flight F33 at Gate 13 to Gate 15: 37.0
# Flow from Flight F33 at Gate 13 to Exit: 115.0
# Flow from Flight F34 at Gate 10 to Gate 12: 8.0
# Flow from Flight F34 at Gate 10 to Gate 21: 41.0
# Flow from Flight F34 at Gate 10 to Exit: 71.0
# Flow from Flight F35 at Gate 4 to Gate 1: 34.0
# Flow from Flight F35 at Gate 4 to Gate 3: 3.0
# Flow from Flight F35 at Gate 4 to Exit: 156.0
# Flow from Flight F36 at Gate 21 to Gate 3: 6.0
# Flow from Flight F36 at Gate 21 to Gate 21: 24.0
# Flow from Flight F36 at Gate 21 to Exit: 270.0
# Flow from Flight F37 at Gate 2 to Gate 1: 7.0
# Flow from Flight F37 at Gate 2 to Gate 4: 30.0
# Flow from Flight F37 at Gate 2 to Exit: 67.0
# Flow from Flight F38 at Gate 3 to Gate 8: 14.0
# Flow from Flight F38 at Gate 3 to Gate 12: 33.0
# Flow from Flight F38 at Gate 3 to Exit: 172.0
# Flow from Flight F39 at Gate 14 to Gate 9: 23.0
# Flow from Flight F39 at Gate 14 to Apron: 41.0
# Flow from Flight F39 at Gate 14 to Exit: 175.0
# Flow from Flight F40 at Gate 13 to Gate 11: 14.0
# Flow from Flight F40 at Gate 13 to Gate 21: 26.0
# Flow from Flight F40 at Gate 13 to Exit: 71.0
# Flow from Flight F41 at Gate 13 to Gate 11: 31.0
# Flow from Flight F41 at Gate 13 to Gate 14: 8.0
# Flow from Flight F41 at Gate 13 to Exit: 127.0
# Flow from Flight F42 at Apron to Gate 8: 46.0
# Flow from Flight F42 at Apron to Apron: 5.0
# Flow from Flight F42 at Apron to Exit: 191.0
# Flow from Flight F43 at Gate 8 to Gate 20: 44.0
# Flow from Flight F43 at Gate 8 to Apron: 34.0
# Flow from Flight F43 at Gate 8 to Exit: 89.0
# Flow from Flight F44 at Gate 20 to Gate 2: 47.0
# Flow from Flight F44 at Gate 20 to Gate 15: 13.0
# Flow from Flight F44 at Gate 20 to Exit: 218.0
# Flow from Flight F45 at Gate 14 to Gate 13: 24.0
# Flow from Flight F45 at Gate 14 to Gate 14: 22.0
# Flow from Flight F45 at Gate 14 to Exit: 149.0
# Flow from Flight F46 at Gate 8 to Gate 7: 15.0
# Flow from Flight F46 at Gate 8 to Gate 21: 42.0
# Flow from Flight F46 at Gate 8 to Exit: 87.0
# Flow from Flight F47 at Gate 14 to Gate 12: 3.0
# Flow from Flight F47 at Gate 14 to Apron: 41.0
# Flow from Flight F47 at Gate 14 to Exit: 175.0
# Flow from Flight F48 at Gate 21 to Gate 9: 48.0
# Flow from Flight F48 at Gate 21 to Gate 13: 11.0
# Flow from Flight F48 at Gate 21 to Exit: 194.0
# Flow from Flight F49 at Gate 13 to Gate 12: 26.0
# Flow from Flight F49 at Gate 13 to Gate 14: 49.0
# Flow from Flight F49 at Gate 13 to Exit: 83.0
# Flow from Flight F50 at Gate 11 to Gate 2: 5.0
# Flow from Flight F50 at Gate 11 to Gate 15: 17.0
# Flow from Flight F50 at Gate 11 to Exit: 254.0
# Flow from Flight F51 at Gate 6 to Gate 5: 33.0
# Flow from Flight F51 at Gate 6 to Gate 14: 15.0
# Flow from Flight F51 at Gate 6 to Exit: 68.0
# Flow from Flight F52 at Gate 4 to Gate 11: 34.0
# Flow from Flight F52 at Gate 4 to Gate 16: 35.0
# Flow from Flight F52 at Gate 4 to Exit: 92.0
# Flow from Flight F53 at Gate 16 to Gate 15: 13.0
# Flow from Flight F53 at Gate 16 to Gate 22: 27.0
# Flow from Flight F53 at Gate 16 to Exit: 269.0
# Flow from Flight F54 at Gate 23 to Gate 12: 32.0
# Flow from Flight F54 at Gate 23 to Gate 21: 24.0
# Flow from Flight F54 at Gate 23 to Exit: 241.0
# Flow from Flight F55 at Gate 15 to Gate 7: 40.0
# Flow from Flight F55 at Gate 15 to Gate 8: 34.0
# Flow from Flight F55 at Gate 15 to Exit: 186.0
# Flow from Flight F56 at Gate 9 to Gate 14: 8.0
# Flow from Flight F56 at Gate 9 to Gate 15: 11.0
# Flow from Flight F56 at Gate 9 to Exit: 97.0
# Flow from Flight F57 at Gate 25 to Gate 7: 37.0
# Flow from Flight F57 at Gate 25 to Gate 21: 33.0
# Flow from Flight F57 at Gate 25 to Exit: 180.0
# Flow from Flight F58 at Gate 11 to Gate 8: 5.0
# Flow from Flight F58 at Gate 11 to Exit: 278.0
# Flow from Flight F59 at Gate 11 to Gate 8: 31.0
# Flow from Flight F59 at Gate 11 to Gate 15: 43.0
# Flow from Flight F59 at Gate 11 to Exit: 184.0
# Flow from Flight F60 at Gate 8 to Gate 7: 43.0
# Flow from Flight F60 at Gate 8 to Apron: 18.0
# Flow from Flight F60 at Gate 8 to Exit: 95.0
# Flow from Flight F61 at Gate 9 to Gate 10: 45.0
# Flow from Flight F61 at Gate 9 to Gate 25: 26.0
# Flow from Flight F61 at Gate 9 to Exit: 169.0
# Flow from Flight F62 at Gate 15 to Gate 12: 42.0
# Flow from Flight F62 at Gate 15 to Gate 20: 14.0
# Flow from Flight F62 at Gate 15 to Exit: 188.0
# Flow from Flight F63 at Gate 6 to Gate 11: 31.0
# Flow from Flight F63 at Gate 6 to Gate 25: 47.0
# Flow from Flight F63 at Gate 6 to Exit: 80.0
# Flow from Flight F64 at Gate 1 to Gate 12: 21.0
# Flow from Flight F64 at Gate 1 to Apron: 15.0
# Flow from Flight F64 at Gate 1 to Exit: 278.0
# Flow from Flight F65 at Gate 12 to Gate 1: 8.0
# Flow from Flight F65 at Gate 12 to Exit: 194.0
# Flow from Flight F66 at Gate 15 to Gate 7: 33.0
# Flow from Flight F66 at Gate 15 to Gate 9: 33.0
# Flow from Flight F66 at Gate 15 to Exit: 161.0
# Flow from Flight F67 at Gate 3 to Gate 5: 47.0
# Flow from Flight F67 at Gate 3 to Gate 20: 25.0
# Flow from Flight F67 at Gate 3 to Exit: 89.0
# Flow from Flight F68 at Gate 3 to Gate 20: 22.0
# Flow from Flight F68 at Gate 3 to Apron: 27.0
# Flow from Flight F68 at Gate 3 to Exit: 179.0
# Flow from Flight F69 at Gate 16 to Gate 18: 40.0
# Flow from Flight F69 at Gate 16 to Gate 20: 41.0
# Flow from Flight F69 at Gate 16 to Exit: 165.0
# Flow from Flight F70 at Gate 12 to Gate 21: 5.0
# Flow from Flight F70 at Gate 12 to Apron: 15.0
# Flow from Flight F70 at Gate 12 to Exit: 87.0
# Flow from Flight F71 at Gate 21 to Gate 8: 49.0
# Flow from Flight F71 at Gate 21 to Gate 20: 8.0
# Flow from Flight F71 at Gate 21 to Exit: 197.0
# Flow from Flight F72 at Gate 3 to Gate 3: 36.0
# Flow from Flight F72 at Gate 3 to Gate 13: 18.0
# Flow from Flight F72 at Gate 3 to Exit: 171.0
# Flow from Flight F73 at Gate 25 to Gate 3: 42.0
# Flow from Flight F73 at Gate 25 to Gate 8: 7.0
# Flow from Flight F73 at Gate 25 to Exit: 252.0
# Flow from Flight F74 at Gate 5 to Gate 8: 10.0
# Flow from Flight F74 at Gate 5 to Gate 9: 7.0
# Flow from Flight F74 at Gate 5 to Exit: 322.0
# Flow from Flight F75 at Gate 5 to Gate 7: 33.0
# Flow from Flight F75 at Gate 5 to Gate 16: 37.0
# Flow from Flight F75 at Gate 5 to Exit: 270.0
# Flow from Flight F76 at Apron to Gate 1: 38.0
# Flow from Flight F76 at Apron to Exit: 92.0
# Flow from Flight F77 at Gate 2 to Gate 7: 14.0
# Flow from Flight F77 at Gate 2 to Gate 9: 3.0
# Flow from Flight F77 at Gate 2 to Exit: 207.0
# Flow from Flight F78 at Apron to Gate 13: 15.0
# Flow from Flight F78 at Apron to Gate 21: 42.0
# Flow from Flight F78 at Apron to Exit: 201.0
# Flow from Flight F79 at Gate 7 to Gate 1: 9.0
# Flow from Flight F79 at Gate 7 to Gate 4: 37.0
# Flow from Flight F79 at Gate 7 to Exit: 57.0
# Flow from Flight F80 at Gate 1 to Gate 8: 15.0
# Flow from Flight F80 at Gate 1 to Apron: 44.0
# Flow from Flight F80 at Gate 1 to Exit: 264.0
# Flow from Flight F81 at Gate 1 to Gate 2: 5.0
# Flow from Flight F81 at Gate 1 to Gate 18: 32.0
# Flow from Flight F81 at Gate 1 to Exit: 227.0
# Flow from Flight F82 at Gate 10 to Gate 8: 38.0
# Flow from Flight F82 at Gate 10 to Gate 12: 14.0
# Flow from Flight F82 at Gate 10 to Exit: 98.0
# Flow from Flight F83 at Gate 15 to Gate 1: 19.0
# Flow from Flight F83 at Gate 15 to Gate 13: 35.0
# Flow from Flight F83 at Gate 15 to Exit: 92.0
# Flow from Flight F84 at Gate 2 to Gate 1: 35.0
# Flow from Flight F84 at Gate 2 to Gate 11: 48.0
# Flow from Flight F84 at Gate 2 to Exit: 135.0
# Flow from Flight F85 at Gate 3 to Gate 11: 9.0
# Flow from Flight F85 at Gate 3 to Gate 21: 13.0
# Flow from Flight F85 at Gate 3 to Exit: 211.0
# Flow from Flight F86 at Gate 6 to Gate 8: 36.0
# Flow from Flight F86 at Gate 6 to Gate 13: 11.0
# Flow from Flight F86 at Gate 6 to Exit: 106.0
# Flow from Flight F87 at Gate 5 to Gate 7: 20.0
# Flow from Flight F87 at Gate 5 to Gate 17: 39.0
# Flow from Flight F87 at Gate 5 to Exit: 200.0
# Flow from Flight F88 at Gate 13 to Gate 12: 35.0
# Flow from Flight F88 at Gate 13 to Gate 15: 22.0
# Flow from Flight F88 at Gate 13 to Exit: 161.0
# Flow from Flight F89 at Gate 12 to Gate 11: 13.0
# Flow from Flight F89 at Gate 12 to Gate 20: 18.0
# Flow from Flight F89 at Gate 12 to Exit: 168.0
# Flow from Flight F90 at Gate 1 to Gate 25: 33.0
# Flow from Flight F90 at Gate 1 to Exit: 311.0
# Flow from Flight F91 at Apron to Gate 21: 74.0
# Flow from Flight F91 at Apron to Exit: 185.0
# Flow from Flight F92 at Gate 8 to Gate 1: 15.0
# Flow from Flight F92 at Gate 8 to Gate 3: 36.0
# Flow from Flight F92 at Gate 8 to Exit: 55.0
# Flow from Flight F93 at Gate 9 to Gate 4: 7.0
# Flow from Flight F93 at Gate 9 to Gate 20: 13.0
# Flow from Flight F93 at Gate 9 to Exit: 115.0
# Flow from Flight F94 at Gate 15 to Gate 2: 10.0
# Flow from Flight F94 at Gate 15 to Gate 13: 14.0
# Flow from Flight F94 at Gate 15 to Exit: 285.0
# Flow from Flight F95 at Gate 1 to Gate 13: 5.0
# Flow from Flight F95 at Gate 1 to Exit: 303.0
# Flow from Flight F96 at Gate 7 to Gate 8: 49.0
# Flow from Flight F96 at Gate 7 to Gate 21: 31.0
# Flow from Flight F96 at Gate 7 to Exit: 86.0
# Flow from Flight F97 at Gate 21 to Gate 4: 3.0
# Flow from Flight F97 at Gate 21 to Gate 21: 32.0
# Flow from Flight F97 at Gate 21 to Exit: 294.0
# Flow from Flight F98 at Gate 20 to Gate 1: 3.0
# Flow from Flight F98 at Gate 20 to Gate 12: 36.0
# Flow from Flight F98 at Gate 20 to Exit: 214.0
# Flow from Flight F99 at Gate 18 to Gate 21: 50.0
# Flow from Flight F99 at Gate 18 to Exit: 242.0
# Flow from Flight F100 at Gate 17 to Gate 6: 30.0
# Flow from Flight F100 at Gate 17 to Gate 7: 23.0
# Flow from Flight F100 at Gate 17 to Exit: 100.0

# %%
# Optimize model
model.optimize()

# Create a dictionary to store flight assignments
flight_assignments = {}

# Collect flight assignments to gates
if model.status == GRB.OPTIMAL:
    for i in range(num_flights):
        for k in range(num_gates + 1):
            if x[i, k].X > 0.5:  # Check if the flight is assigned to the gate
                gate = 'Apron' if k == num_gates else gate_ids[k]
                flight_assignments[flight_data.loc[i, 'flight_id']] = {
                    'gate': gate,
                    'arrival_time': flight_data.loc[i, 'arrival_time'],
                    'departure_time': flight_data.loc[i, 'departure_time']
                }

    # Plot the flight assignments
    fig, ax = plt.subplots(figsize=(15, 10))

    for flight_id, info in flight_assignments.items():
        gate = info['gate']
        arrival_time = info['arrival_time']
        departure_time = info['departure_time']
        gate_num = gate_ids.index(gate) + 1 if gate != 'Apron' else num_gates + 1

        ax.broken_barh([(arrival_time, departure_time - arrival_time)], (gate_num - 0.4, 0.8),
                       facecolors=('tab:blue'), edgecolors=('black'))
        ax.text((arrival_time + departure_time) / 2, gate_num, flight_id,
                ha='center', va='center', color='white')

    # Set labels and title
    ax.set_xlabel('Time (minutes since midnight)')
    ax.set_ylabel('Gate Number')
    ax.set_title('Flight Assignments to Gates Over Time')
    ax.set_yticks(range(1, num_gates + 2))
    ax.set_yticklabels(gate_ids + ['Apron'])
    ax.grid(True)

    plt.show()
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 63881 rows, 70200 columns and 263718 nonzeros
# Model fingerprint: 0x9c31236c
# Variable types: 67600 continuous, 2600 integer (2600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   Objective range  [2e+00, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Presolved: 4175 rows, 29371 columns, 65064 nonzeros
#
# Continuing optimization...
#
#
# Cutting planes:
#   Implied bound: 190
#   MIR: 131
#   Flow cover: 581
#   Inf proof: 4
#   RLT: 5
#   Relax-and-lift: 33
#
# Explored 4927 nodes (1289112 simplex iterations) in 0.05 seconds (0.03 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 309271 309327 309431 ... 328642
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.092710000000e+05, best bound 3.092710000000e+05, gap 0.0000%

# %%
# Create a list to store information about large flights and their assignments
large_flight_assignments = []

# Collect flight assignments for large flights
if model.status == GRB.OPTIMAL:
    for i in range(num_flights):
        if i in large_aircraft:
            for k in range(num_gates + 1):
                if x[i, k].X > 0.5:  # Check if the flight is assigned to the gate
                    gate = 'Apron' if k == num_gates else gate_ids[k]
                    gate_type = 'Large' if k in [0, 4, 10, 14, 15, 17, 19, 20, 22, 24] else 'Normal'
                    gate_flight_type = 'None' if k == num_gates else ('Domestic' if k in K_D else 'International')
                    flight_info = {
                        'flight_id': flight_data.loc[i, 'flight_id'],
                        'flight_type': flight_data.loc[i, 'flight_type'],
                        'assigned_gate': gate,
                        'gate_type': gate_type,
                        'gate_flight_type': gate_flight_type
                    }
                    large_flight_assignments.append(flight_info)

# Print the large flight assignments
for flight in large_flight_assignments:
    print(f"Flight {flight['flight_id']} : {flight['flight_type']}, assigned to gate: {flight['assigned_gate']} : {flight['gate_type']}: {flight['gate_flight_type']}")
# Out:
# Flight F03 : International, assigned to gate: Gate 11 : Large: International
# Flight F04 : International, assigned to gate: Gate 20 : Large: International
# Flight F05 : International, assigned to gate: Gate 11 : Large: International
# Flight F11 : International, assigned to gate: Gate 11 : Large: International
# Flight F13 : International, assigned to gate: Gate 20 : Large: International
# Flight F21 : International, assigned to gate: Gate 20 : Large: International
# Flight F23 : International, assigned to gate: Gate 21 : Large: International
# Flight F31 : International, assigned to gate: Gate 11 : Large: International
# Flight F36 : International, assigned to gate: Gate 21 : Large: International
# Flight F42 : International, assigned to gate: Apron : Normal: None
# Flight F44 : International, assigned to gate: Gate 20 : Large: International
# Flight F48 : International, assigned to gate: Gate 21 : Large: International
# Flight F50 : International, assigned to gate: Gate 11 : Large: International
# Flight F53 : Domestic, assigned to gate: Gate 16 : Large: Domestic
# Flight F54 : Domestic, assigned to gate: Gate 23 : Large: Domestic
# Flight F55 : Domestic, assigned to gate: Gate 15 : Large: Domestic
# Flight F57 : Domestic, assigned to gate: Gate 25 : Large: Domestic
# Flight F58 : International, assigned to gate: Gate 11 : Large: International
# Flight F59 : International, assigned to gate: Gate 11 : Large: International
# Flight F62 : Domestic, assigned to gate: Gate 15 : Large: Domestic
# Flight F64 : Domestic, assigned to gate: Gate 1 : Large: Domestic
# Flight F69 : Domestic, assigned to gate: Gate 16 : Large: Domestic
# Flight F71 : International, assigned to gate: Gate 21 : Large: International
# Flight F73 : Domestic, assigned to gate: Gate 25 : Large: Domestic
# Flight F74 : Domestic, assigned to gate: Gate 5 : Large: Domestic
# Flight F75 : Domestic, assigned to gate: Gate 5 : Large: Domestic
# Flight F78 : International, assigned to gate: Apron : Normal: None
# Flight F80 : Domestic, assigned to gate: Gate 1 : Large: Domestic
# Flight F81 : Domestic, assigned to gate: Gate 1 : Large: Domestic
# Flight F87 : Domestic, assigned to gate: Gate 5 : Large: Domestic
# Flight F90 : Domestic, assigned to gate: Gate 1 : Large: Domestic
# Flight F91 : International, assigned to gate: Apron : Normal: None
# Flight F94 : Domestic, assigned to gate: Gate 15 : Large: Domestic
# Flight F95 : Domestic, assigned to gate: Gate 1 : Large: Domestic
# Flight F97 : International, assigned to gate: Gate 21 : Large: International
# Flight F98 : International, assigned to gate: Gate 20 : Large: International
# Flight F99 : International, assigned to gate: Gate 18 : Large: International

# %%
# Optimize model
model.optimize()

# Objective function components
transfer_distance_component = quicksum(d_kl[k, l] * w[i, k, l] for i in range(num_flights) for k in range(num_gates + 1) for l in range(num_gates + 1))
normal_distance_component = quicksum((e_i[i] + f_i[i]) * ed_k[k] * x[i, k] for i in range(num_flights) for k in range(num_gates + 1))

if model.status == GRB.OPTIMAL:
    transfer_distance = 0
    normal_distance = 0
    apron_count = 0
    
    for i in range(num_flights):
        for k in range(num_gates + 1):
            for l in range(num_gates + 1):
                if w[i, k, l].X > 0:
                    transfer_distance += d_kl[k, l] * w[i, k, l].X

    for i in range(num_flights):
        for k in range(num_gates + 1):
            if x[i, k].X > 0.5:
                normal_distance += (e_i[i] + f_i[i]) * ed_k[k] * x[i, k].X
                if k == num_gates:  # Check if assigned to apron
                    apron_count += 1

    print(f"\nObjective Transfer Distance Component: {transfer_distance}")
    print(f"Objective Normal Distance Component: {normal_distance}")
    print(f"Objective Function Value: {model.objVal}")
    print(f"Number of flights assigned to the apron: {apron_count}")

else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 63881 rows, 70200 columns and 263718 nonzeros
# Model fingerprint: 0x9c31236c
# Variable types: 67600 continuous, 2600 integer (2600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   Objective range  [2e+00, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Presolved: 4175 rows, 29371 columns, 65064 nonzeros
#
# Continuing optimization...
#
#
# Cutting planes:
#   Implied bound: 190
#   MIR: 131
#   Flow cover: 581
#   Inf proof: 4
#   RLT: 5
#   Relax-and-lift: 33
#
# Explored 4927 nodes (1289112 simplex iterations) in 0.07 seconds (0.03 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 309271 309327 309431 ... 328642
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.092710000000e+05, best bound 3.092710000000e+05, gap 0.0000%
#
# Objective Transfer Distance Component: 47732.0
# Objective Normal Distance Component: 261539.0
# Objective Function Value: 309271.0
# Number of flights assigned to the apron: 7
